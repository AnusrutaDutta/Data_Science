# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Red wine dataset

# %% [markdown]
# ## Import the dataset

# %%
red_wine=pd.read_csv('winequality-red.csv',sep=';')
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
red_wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
red_wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## Ploting the all columns with alcohol in redwine dataframe

# %%
plt.figure(figsize=(50,40))
plt.subplot(3,4,1)
plt.scatter(red_wine['fixed acidity'],red_wine.alcohol)
plt.title('fixed acidity')
plt.subplot(3,4,2)
plt.scatter(red_wine['volatile acidity'],red_wine.alcohol)
plt.title('volatile acidity')

plt.subplot(3,4,3)
plt.scatter(red_wine['citric acid'],red_wine.alcohol)
plt.title('citric acid')

plt.subplot(3,4,4)
plt.scatter(red_wine['residual sugar'],red_wine.alcohol)
plt.title('residual sugar')

plt.subplot(3,4,5)
plt.scatter(red_wine['chlorides'],red_wine.alcohol)
plt.title('chlorides')

plt.subplot(3,4,6)
plt.scatter(red_wine['free sulfur dioxide'],red_wine.alcohol)
plt.title('free sulfur dioxide')

plt.subplot(3,4,7)
plt.scatter(red_wine['total sulfur dioxide'],red_wine.alcohol)
plt.title('total sulfur dioxide')

plt.subplot(3,4,8)
plt.scatter(red_wine['density'],red_wine.alcohol)
plt.title('density')

plt.subplot(3,4,9)
plt.scatter(red_wine['pH'],red_wine.alcohol)
plt.title('pH')

plt.subplot(3,4,10)
plt.scatter(red_wine['sulphates'],red_wine.alcohol)
plt.title('sulphates')

plt.subplot(3,4,11)
plt.scatter(red_wine['quality'],red_wine.alcohol)
plt.title('quality')
# Out:
# Text(0.5, 1.0, 'quality')

# %% [markdown]
# ## Distplot

# %%
plt.figure(figsize=(50,40))
plt.subplot(3,4,1)
sns.distplot(red_wine['fixed acidity'])
plt.subplot(3,4,2)
sns.distplot(red_wine['volatile acidity'])
plt.subplot(3,4,3)
sns.distplot(red_wine['citric acid'])
plt.subplot(3,4,4)
sns.distplot(red_wine['residual sugar'])
plt.subplot(3,4,5)
sns.distplot(red_wine['chlorides'])
plt.subplot(3,4,6)
sns.distplot(red_wine['free sulfur dioxide'])
plt.subplot(3,4,7)
sns.distplot(red_wine['total sulfur dioxide'])
plt.subplot(3,4,8)
sns.distplot(red_wine['density'])
plt.subplot(3,4,9)
sns.distplot(red_wine['pH'])
plt.subplot(3,4,10)
sns.distplot(red_wine['sulphates'])
plt.subplot(3,4,11)
sns.distplot(red_wine.alcohol)
plt.subplot(3,4,12)
sns.distplot(red_wine['quality'])

# %%
red_wine.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# ## Removing the outliers og 99%

# %%
red_wine_new=red_wine['chlorides'].quantile(0.95)

# %% [markdown]
# ## Removing the put liers from -3sigma to 3sigma

# %%
red_wine_res_out.shape
# Out:
# (1484, 12)

# %%
red_wine_res_out.skew()
# Out:
# fixed acidity           0.964035
# volatile acidity        0.689004
# citric acid             0.306684
# residual sugar          1.888540
# chlorides               1.792553
# free sulfur dioxide     1.056448
# total sulfur dioxide    1.244448
# density                -0.036398
# pH                      0.282486
# sulphates               0.856475
# alcohol                 0.830046
# quality                 0.232427
# dtype: float64

# %%
red_wine_res_out=red_wine[(red_wine['residual sugar']>(np.mean(red_wine['residual sugar'])-3*np.std(red_wine['residual sugar']))) & (red_wine['residual sugar']<(np.mean(red_wine['residual sugar'])+2.15*np.std(red_wine['residual sugar'])))]

# %%
red_wine_res_out.shape
# Out:
# (1533, 12)

# %%
red_wine_res_out=red_wine_res_out[(red_wine['chlorides']>(np.mean(red_wine['chlorides'])-3*np.std(red_wine['chlorides']))) & (red_wine['chlorides']<(np.mean(red_wine['chlorides'])+2.7*np.std(red_wine['chlorides'])))]

# %%
red_wine_res_out.shape
# Out:
# (1499, 12)

# %%
red_wine_res_out=red_wine_res_out[(red_wine['sulphates']>(np.mean(red_wine['sulphates'])-3*np.std(red_wine['sulphates']))) & (red_wine['sulphates']<(np.mean(red_wine['sulphates'])+3*np.std(red_wine['sulphates'])))]

# %%
red_wine_res_out.shape
# Out:
# (1484, 12)

# %%
red_wine_res_out.skew()
# Out:
# fixed acidity           0.964035
# volatile acidity        0.689004
# citric acid             0.306684
# residual sugar          1.888540
# chlorides               1.792553
# free sulfur dioxide     1.056448
# total sulfur dioxide    1.244448
# density                -0.036398
# pH                      0.282486
# sulphates               0.856475
# alcohol                 0.830046
# quality                 0.232427
# dtype: float64

# %%
plt.figure(figsize=(50,40))
plt.subplot(3,4,1)
sns.distplot(red_wine_res_out['fixed acidity'])
plt.subplot(3,4,2)
sns.distplot(red_wine_res_out['volatile acidity'])
plt.subplot(3,4,3)
sns.distplot(red_wine_res_out['citric acid'])
plt.subplot(3,4,4)
sns.distplot(red_wine_res_out['residual sugar'])
plt.subplot(3,4,5)
sns.distplot(red_wine_res_out['chlorides'])
plt.subplot(3,4,6)
sns.distplot(red_wine_res_out['free sulfur dioxide'])
plt.subplot(3,4,7)
sns.distplot(red_wine_res_out['total sulfur dioxide'])
plt.subplot(3,4,8)
sns.distplot(red_wine_res_out['density'])
plt.subplot(3,4,9)
sns.distplot(red_wine_res_out['pH'])
plt.subplot(3,4,10)
sns.distplot(red_wine_res_out['sulphates'])
plt.subplot(3,4,11)
sns.distplot(red_wine_res_out.alcohol)
plt.subplot(3,4,12)
sns.distplot(red_wine_res_out['quality'])

# %%
plt.figure(figsize=(20,20))
plt.subplot(3,4,1)
plt.scatter(red_wine_res_out['fixed acidity'],red_wine_res_out.pH,)
plt.xlabel('fixed acidity')
plt.ylabel('pH')

plt.subplot(3,4,2)
plt.scatter(red_wine_res_out['volatile acidity'],red_wine_res_out.pH)
plt.xlabel('volatile acidity')
plt.ylabel('pH')

plt.subplot(3,4,3)
plt.scatter(red_wine_res_out['citric acid'],red_wine_res_out.pH)
plt.xlabel('citric acid')
plt.ylabel('pH')

plt.subplot(3,4,4)
plt.scatter(red_wine_res_out['residual sugar'],red_wine_res_out.pH)
plt.xlabel('residual sugar')
plt.ylabel('pH')

plt.subplot(3,4,5)
plt.scatter(red_wine_res_out['chlorides'],red_wine_res_out.pH)
plt.xlabel('chlorides')
plt.ylabel('pH')

plt.subplot(3,4,6)
plt.scatter(red_wine_res_out['free sulfur dioxide'],red_wine_res_out.pH)
plt.xlabel('free sulfur dioxide')
plt.ylabel('pH')

plt.subplot(3,4,7)
plt.scatter(red_wine_res_out['total sulfur dioxide'],red_wine_res_out.pH)
plt.xlabel('total sulfur dioxide')
plt.ylabel('pH')

plt.subplot(3,4,8)
plt.scatter(red_wine_res_out['density'],red_wine_res_out.pH)
plt.xlabel('density')
plt.ylabel('pH')

plt.subplot(3,4,9)
plt.scatter(red_wine_res_out['sulphates'],red_wine_res_out.pH)
plt.xlabel('sulphates')
plt.ylabel('pH')

plt.subplot(3,4,10)
plt.scatter(red_wine_res_out['alcohol'],red_wine_res_out.pH)
plt.xlabel('alcohol')
plt.ylabel('pH')

plt.subplot(3,4,11)
plt.scatter(red_wine_res_out['quality'],red_wine_res_out.pH,color='rgba')
plt.xlabel('quality')
plt.ylabel('pH')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4218             try:
# -> 4219                 mcolors.to_rgba_array(kwcolor)
#    4220             except ValueError:
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     285     for i, cc in enumerate(c):
# --> 286         result[i] = to_rgba(cc, alpha)
#     287     return result
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     230             pass
# --> 231         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     232     # tuple color.
#
# ValueError: Invalid RGBA argument: 'a'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-297-fa7b17b3e1c7> in <module>
#      51
#      52 plt.subplot(3,4,11)
# ---> 53 plt.scatter(red_wine_res_out['quality'],red_wine_res_out.pH,color='rgba')
#      54 plt.xlabel('quality')
#      55 plt.ylabel('pH')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2839         verts=verts, edgecolors=edgecolors,
#    2840         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2841         None else {}), **kwargs)
#    2842     sci(__ret)
#    2843     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4444             self._parse_scatter_color_args(
#    4445                 c, edgecolors, kwargs, xshape, yshape,
# -> 4446                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4447
#    4448         if plotnonfinite and colors is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4219                 mcolors.to_rgba_array(kwcolor)
#    4220             except ValueError:
# -> 4221                 raise ValueError("'color' kwarg must be an mpl color"
#    4222                                  " spec or sequence of color specs.\n"
#    4223                                  "For a sequence of values to be color-mapped,"
#
# ValueError: 'color' kwarg must be an mpl color spec or sequence of color specs.
# For a sequence of values to be color-mapped, use the 'c' argument instead.

# %%
red_wine_res_out.corr()

# %% [markdown]
# ## heatmap

# %%
plt.figure(figsize=(10,10))
sns.heatmap(red_wine_res_out.corr(),annot=True)

# %%
from sklearn.model_selection import train_test_split

# %%
red_wine_train,red_wine_test=train_test_split(red_wine_res_out,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
red_wine_train_scaled=pd.DataFrame(sc.fit_transform(red_wine_train),columns=red_wine_res_out.columns)

# %%
red_wine_test_scaled=pd.DataFrame(sc.transform(red_wine_test),columns=red_wine_res_out.columns)

# %%
red_wine_train_scaled.shape

# %%
red_wine_test_scaled.shape

# %%
X_train=red_wine_train_scaled.drop(['pH'],1)

# %%
X_test=red_wine_test_scaled.drop(['pH'],1)

# %%
y_train=red_wine_train_scaled.pH

# %%
y_test= red_wine_test_scaled.pH

# %% [markdown]
# ## RFE

# %%
from sklearn.feature_selection import RFE

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)

# %%
rfe=RFE(lr,9)

# %%
rfe=rfe.fit(X_train,y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))

# %%
rfe.support_

# %%
selected_col=X_train.columns[rfe.support_]
selected_col

# %%
X_train_rfe=X_train[selected_col]

# %% [markdown]
# ## Statsmodel(sm)

# %%
import statsmodels.api as sm

# %%
X_train_rfe_sm= sm.add_constant(X_train_rfe)
train_ols=sm.OLS(y_train,X_train_rfe_sm).fit()

# %%
print(train_ols.summary())

# %%
X_train_rfe=X_train_rfe.drop(['volatile acidity'],1)

# %%
X_train_rfe_sm=sm.add_constant(X_train_rfe)
train_ols_2=sm.OLS(y_train,X_train_rfe_sm).fit()

# %%
print(train_ols_2.summary())

# %% [markdown]
# ## VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['features']=X_train_rfe.columns
vif['VIF']=[variance_inflation_factor(X_train_rfe.values,i) for i in range(X_train_rfe.shape[1])]
vif= vif.sort_values(by='VIF', ascending=False)
vif

# %%
X_train_rfe.head()

# %%
X_train_rfe_sm.columns

# %%
y_train_sm_pred=train_ols_2.predict(X_train_rfe_sm)

# %%
error_training=y_train-y_train_sm_pred

# %%
sns.distplot(error_training)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_train_sm_pred)

# %% [markdown]
# ## With Test data

# %%
X_test_sm= sm.add_constant(X_test)

# %%
X_test_sm=X_test_sm[X_train_rfe_sm.columns]

# %%
y_test_sm_pred=train_ols_2.predict(X_test_sm)
y_train_sm_pred=train_ols_2.predict(X_train_rfe_sm)

# %%
r2_score(y_test,y_test_sm_pred)

# %% [markdown]
# ## Linear Regression

# %%
lr.fit(X_train_rfe_sm,y_train)

# %%
y_pred_lr=lr.predict(X_test_sm)

# %%
r2_score(y_test,y_pred_lr)
